# %%
from langchain_community.document_loaders import PDFPlumberLoader
from langchain_mistralai.chat_models import ChatMistralAI
from langchain_mistralai.embeddings import MistralAIEmbeddings
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_community.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains import create_retrieval_chain
from dotenv import load_dotenv
from semantic_metrics import *
import pandas as pd
import time
import os

load_dotenv()
# Out:
# True

# %%
DOCS = ["nvidia.pdf", "mastercard.pdf", "microsoft.pdf"]
# mistal-tiny = 7B and mistral-small = 8x7B
MISTRAL_MODELS = ["mistral-tiny", "mistral-small", "mistral-large-2402"]
MISTRAL_EMBEDDINGS = "mistral-embed"
OPENAI_MODELS = ["gpt-4-0125-preview", "gpt-3.5-turbo"]
OPENAI_EMBEDDINGS = "text-embedding-3-large"
GOOGLE_MODELS = ['gemini-1.0-pro-001']
GOOGLE_EMBEDDINGS = 'embedding-001'
# LLM settings
TEMPERATURE = 0.1
TOP_P = 0.2

# %%
def run_mistral_completions(questions, reference_doc, llm_model, embeddings_model, temperature=0.5, top_p=0.5):

    # Load data
    loader = PDFPlumberLoader(reference_doc)
    docs = loader.load()
    # Split text into chunks 
    text_splitter = RecursiveCharacterTextSplitter()
    documents = text_splitter.split_documents(docs)
    # Define the embedding model
    embeddings = MistralAIEmbeddings(model=embeddings_model, mistral_api_key=os.getenv("MISTRAL_API_KEY"))
    # Create the vector store 
    vector = FAISS.from_documents(documents, embeddings)
    # Define a retriever interface
    retriever = vector.as_retriever()
    # Define prompt template
    prompt = ChatPromptTemplate.from_template("""Answer the following question based only on the provided context:

    <context>
    {context}
    </context>

    Question: {input}""")

    # Define LLM
    model = ChatMistralAI(mistral_api_key=os.getenv("MISTRAL_API_KEY"), model=llm_model, temperature=temperature, top_p=top_p)

    # Create a retrieval chain to answer questions
    document_chain = create_stuff_documents_chain(model, prompt)
    retrieval_chain = create_retrieval_chain(retriever, document_chain)

    answers = []
    times = []
    for question in questions:
        start = time.time()
        response = retrieval_chain.invoke({"input": question})
        total_time = time.time() - start
        answer = response["answer"]
        answers.append(answer)
        times.append(total_time)

    return answers, times

def run_openai_completions(questions, reference_doc, llm_model, embeddings_model, temperature=0.5, top_p=0.5):

    # Load data
    loader = PDFPlumberLoader(reference_doc)
    docs = loader.load()
    # Split text into chunks 
    text_splitter = RecursiveCharacterTextSplitter()
    documents = text_splitter.split_documents(docs)
    # Define the embedding model
    embeddings = OpenAIEmbeddings(openai_api_key=os.getenv("OPENAI_API_KEY"), model=embeddings_model)
    # Create the vector store 
    vector = FAISS.from_documents(documents, embeddings)
    # Define a retriever interface
    retriever = vector.as_retriever()
    # Define prompt template
    prompt = ChatPromptTemplate.from_template("""Answer the following question based only on the provided context:

    <context>
    {context}
    </context>

    Question: {input}""")

    # Define LLM
    model = ChatOpenAI(openai_api_key=os.getenv("OPENAI_API_KEY"), model_name=llm_model, temperature=temperature, model_kwargs={"top_p": top_p})

    # Create a retrieval chain to answer questions
    document_chain = create_stuff_documents_chain(model, prompt)
    retrieval_chain = create_retrieval_chain(retriever, document_chain)

    answers = []
    times = []
    for question in questions:
        start = time.time()
        response = retrieval_chain.invoke({"input": question})
        total_time = time.time() - start
        answer = response["answer"]
        answers.append(answer)
        times.append(total_time)

    return answers, times

def run_google_completions(questions, reference_doc, llm_model, embeddings_model, temperature=0.5, top_p=0.5):

    # Load data
    loader = PDFPlumberLoader(reference_doc)
    docs = loader.load()
    # Split text into chunks 
    text_splitter = RecursiveCharacterTextSplitter()
    documents = text_splitter.split_documents(docs)
    # Define the embedding model
    embeddings = GoogleGenerativeAIEmbeddings(model=f'models/{embeddings_model}')
    # Create the vector store 
    vector = FAISS.from_documents(documents, embeddings)
    # Define a retriever interface
    retriever = vector.as_retriever()
    # Define prompt template
    prompt = ChatPromptTemplate.from_template("""Answer the following question based only on the provided context:

    <context>
    {context}
    </context>

    Question: {input}""")

    # Define LLM
    model = ChatGoogleGenerativeAI(
        google_api_key=os.getenv("GOOGLE_API_KEY"),
        model=f'models/{llm_model}',
        temperature=temperature,
        top_p=top_p
    )

    # Create a retrieval chain to answer questions
    document_chain = create_stuff_documents_chain(model, prompt)
    retrieval_chain = create_retrieval_chain(retriever, document_chain)

    answers = []
    times = []
    for question in questions:
        start = time.time()
        response = retrieval_chain.invoke({"input": question})
        total_time = time.time() - start
        answer = response["answer"]
        answers.append(answer)
        times.append(total_time)

    return answers, times

# %%
# Load set of questions
questions_df = pd.read_csv('questions.csv')

df_list = []

# Run completions
for doc in DOCS:
    print(doc)
    print()
    doc_df = questions_df[questions_df['ReferenceDoc'] == doc]
    doc_path = f'docs/{doc}'
    for model in MISTRAL_MODELS:
        print(model)
        mistral_answers, mistral_times = run_mistral_completions(
            doc_df['Question'].to_list(),
            doc_path,
            llm_model=model,
            embeddings_model=MISTRAL_EMBEDDINGS,
            temperature=TEMPERATURE,
            top_p=TOP_P
        )
        doc_df[f'{model}_response'] = mistral_answers
        doc_df[f'{model}_time'] = mistral_times

    for model in OPENAI_MODELS:
        print(model)
        openai_answers, openai_times = run_openai_completions(
            doc_df['Question'].to_list(),
            doc_path,
            llm_model=model,
            embeddings_model=OPENAI_EMBEDDINGS,
            temperature=TEMPERATURE,
            top_p=TOP_P
        )
        doc_df[f'{model}_response'] = openai_answers
        doc_df[f'{model}_time'] = openai_times

    for model in GOOGLE_MODELS:
        print(model)
        google_answers, google_times = run_google_completions(
            doc_df['Question'].to_list(),
            doc_path,
            llm_model=model,
            embeddings_model=GOOGLE_EMBEDDINGS,
            temperature=TEMPERATURE,
            top_p=TOP_P
        )
        doc_df[f'{model}_response'] = google_answers
        doc_df[f'{model}_time'] = google_times
    
    df_list.append(doc_df)

responses_df = pd.concat(df_list)
# Out:
# nvidia.pdf
#
# gemini-1.0-pro-001
# /var/folders/tf/rp1vqsws5nq6gh7ndddbtl1h0000gn/T/ipykernel_39776/514868342.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   doc_df[f'{model}_response'] = google_answers
# /var/folders/tf/rp1vqsws5nq6gh7ndddbtl1h0000gn/T/ipykernel_39776/514868342.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   doc_df[f'{model}_time'] = google_times
# mastercard.pdf
#
# gemini-1.0-pro-001
# /var/folders/tf/rp1vqsws5nq6gh7ndddbtl1h0000gn/T/ipykernel_39776/514868342.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   doc_df[f'{model}_response'] = google_answers
# /var/folders/tf/rp1vqsws5nq6gh7ndddbtl1h0000gn/T/ipykernel_39776/514868342.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   doc_df[f'{model}_time'] = google_times
# microsoft.pdf
#
# gemini-1.0-pro-001
# /var/folders/tf/rp1vqsws5nq6gh7ndddbtl1h0000gn/T/ipykernel_39776/514868342.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   doc_df[f'{model}_response'] = google_answers
# /var/folders/tf/rp1vqsws5nq6gh7ndddbtl1h0000gn/T/ipykernel_39776/514868342.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   doc_df[f'{model}_time'] = google_times

# %%
responses_df
# Out:
#                                              Question  \
# 0   What was Nvidia's total revenue for the quarte...
# 1   What are the primary sources of Nvidia's reven...
# 2   What were Nvidia's total operating expenses fo...
# 3   Were there any significant changes in Nvidia's...
# 4   What is Nvidia's net income for the quarter en...
# 5   What are the company's gross profit margin and...
# 6   What was Nvidia's current ratio (current asset...
# 7   Was there a significant change in Nvidia's cas...
# 8   What was Nvidia's debt-to-equity ratio for the...
# 9   Were there any significant new debts or financ...
# 10  What were the major activities affecting Maste...
# 11  How does Mastercard's free cash flow (operatin...
# 12  What new risk factors did Mastercard disclose ...
# 13  Were there any material changes in the risk fa...
# 14  What key challenges and strategies did Masterc...
# 15  How does Mastercard's management assess the co...
# 16  How did the different business segments of Mas...
# 17  Were there any segments of Mastercard that sig...
# 18  Did Mastercard report any new legal proceeding...
# 19  What are the potential financial impacts of an...
# 20  Which products, services, or market segments c...
# 21  What measures has Microsoft implemented to con...
# 22  How much did Microsoft invest in research and ...
# 23  How have currency fluctuations affected Micros...
# 24  What changes in inventory levels did Microsoft...
# 25  What were Microsoft's capital expenditures dur...
# 26  Did Microsoft buy back any shares or pay divid...
# 27  What was the effective tax rate for Microsoft ...
# 28  Does Microsoft have any significant off-balanc...
# 29  What Environmental, Social and Governance (ESG...
#
#                                                Answer    ReferenceDoc  \
# 0   Nvidia's total revenue for the quarter ended A...      nvidia.pdf
# 1   For the quarter ended April 30, 2023, Nvidia's...      nvidia.pdf
# 2   For the quarter ended April 30, 2023, Nvidia's...      nvidia.pdf
# 3   The COGS as a percentage of revenue increased ...      nvidia.pdf
# 4   Nvidia's net income for the quarter ended Apri...      nvidia.pdf
# 5   For the quarter ended April 30, 2023, Nvidia's...      nvidia.pdf
# 6   As of April 30, 2023, Nvidia's current assets ...      nvidia.pdf
# 7   Yes, there was a significant change in Nvidia'...      nvidia.pdf
# 8                                                0.81      nvidia.pdf
# 9   Nvidia reported outstanding inventory purchase...      nvidia.pdf
# 10  The major activities affecting Mastercard's ca...  mastercard.pdf
# 11         Information not available in the document.  mastercard.pdf
# 12  In the 10-Q report for the quarter ended March...  mastercard.pdf
# 13  Yes, there were material changes in the risk f...  mastercard.pdf
# 14  In the MD&A section for the quarter ended Marc...  mastercard.pdf
# 15  Mastercard's management has assessed the compa...  mastercard.pdf
# 16  Domestic assessments - 19% increase\nCross-bor...  mastercard.pdf
# 17  For the quarter ended March 31, 2022, Masterca...  mastercard.pdf
# 18  Yes, Mastercard reported that it is involved i...  mastercard.pdf
# 19  Mastercard reported that it does not believe a...  mastercard.pdf
# 20  For the quarter ended March 31, 2023, Microsof...   microsoft.pdf
# 21  Microsoft implemented several measures to cont...   microsoft.pdf
# 22  In the quarter ended March 31, 2023, Microsoft...   microsoft.pdf
# 23  Microsoft performs sensitivity analysis to est...   microsoft.pdf
# 24  For the quarter ended March 31, 2023, Microsof...   microsoft.pdf
# 25  During the quarter ended March 31, 2023, Micro...   microsoft.pdf
# 26  During the quarter ended March 31, 2023, Micro...   microsoft.pdf
# 27  The effective tax rate for Microsoft for the q...   microsoft.pdf
# 28  As of March 31, 2023, Microsoft reported havin...   microsoft.pdf
# 29  The document does not specifically list the En...   microsoft.pdf
#
#                           gemini-1.0-pro-001_response  gemini-1.0-pro-001_time
# 0                                      $7,192 million                12.240479
# 1   The primary sources of Nvidia's revenue for th...                 3.429274
# 2   Nvidia's total operating expenses for the quar...                 2.843790
# 3   The provided context does not contain informat...                 2.530924
# 4                                      $2,043 million                 1.843221
# 5   The provided context does not include informat...                 2.457596
# 6   Nvidia's current ratio for the quarter ended A...                 2.867827
# 7   Yes, there was a significant change in Nvidia'...                 2.641461
# 8   The provided context does not include informat...                 1.837309
# 9   The provided context does not mention any sign...                 2.893212
# 10  **Operating Activities:**\n\n* Net income: $2,...                 4.806241
# 11  The provided context does not include informat...                 2.084906
# 12  The provided context does not mention any new ...                 3.611392
# 13  The provided context does not mention any mate...                 1.948491
# 14  The provided context does not include the MD&A...                 3.072335
# 15  The provided context does not contain any info...                 2.558211
# 16  The provided context does not contain informat...                 2.193274
# 17  The provided context does not contain informat...                 1.902980
# 18  The provided context does not mention any new ...                 1.840220
# 19  The provided context does not mention any pote...                 2.570529
# 20  The provided context does not contain informat...                 4.635729
# 21  The provided context does not contain informat...                 3.332911
# 22  Microsoft invested $6,984 million in research ...                 3.083859
# 23  The provided context does not contain informat...                 3.176054
# 24  The provided context does not mention any chan...                 3.378927
# 25  The provided context does not mention Microsof...                 3.991460
# 26  Yes, Microsoft repurchased 18,181,670 shares f...                 4.613523
# 27  The provided context does not contain informat...                 3.322996
# 28  This question cannot be answered from the give...                 4.451439
# 29  The provided context does not contain any info...                 4.610553

# %%
# Evaluate responses
for model in MISTRAL_MODELS + OPENAI_MODELS + GOOGLE_MODELS:
    responses_df[f'{model}_cosine_sim'] = eval_cosine_similarity(
        responses_df['Answer'].to_list(),
        responses_df[f'{model}_response'].to_list(),
        model = 'sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')
    responses_df[f'{model}_bertscore'] = bertscores(
        responses_df['Answer'].to_list(),
        responses_df[f'{model}_response'].to_list())
    token_recall, token_precision = token_recall_precision(
        responses_df['Answer'].to_list(),
        responses_df[f'{model}_response'].to_list())
    responses_df[f'{model}_token_recall'] = token_recall
    responses_df[f'{model}_token_precision'] = token_precision
    responses_df[f'{model}_gpt_evaluation'] = gpt_evaluation(
        responses_df['Question'].to_list(),
        responses_df['Answer'].to_list(),
        responses_df[f'{model}_response'].to_list(),
        key=os.getenv('OPENAI_API_KEY'))

# %%
responses_df.to_csv('responses_df.csv')
